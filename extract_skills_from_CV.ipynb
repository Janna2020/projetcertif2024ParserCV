# %%
# !pip install pdfminer.six
# Out:
# python(97652) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...

# %%
from pdfminer.high_level import extract_text
 
 
def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)
 
 
if __name__ == '__main__':
    print(extract_text_from_pdf('cv_data_project/10005171.pdf'))
# Out:
# MEDIA ACTIVITIES SPECIALIST
# Summary
#
# Multi-Tasking Media Relations Results-oriented
#
# Strategic Initiatives Event Planning Writer & Editor
#
# Manager/Supervisor Flexibility Adaptable
#
# Highlights
#
# Greatly improved media coverage of press
# conferences and other events on campus
# Increased the frequency of newspaper, radio and
# television interviews featuring Chattanooga State
# administrators, faculty and staff
# Hosted popular television show that focused on
# campus and community events (1997-2004)
#
# Accomplishments
#
# Commissioned by local State Representative to produce a historical
# documentary on African American in the Tennessee Legislature from
# Reconstruction to Modern Times (2004)
# Created on-site Spanish language classes for Emergency Room personnel in
# local hospitals when Spanish speaking population began to expand in the
# area (1995)
#
# ...

# %% [markdown]
# ###  Extracting skills from the resumes

# %%
import pdfplumber
from docx import Document

def pdf_to_docx(pdf_path, docx_path):
    # Ouvrir le fichier PDF
    with pdfplumber.open(pdf_path) as pdf:
        text = ""
        # Parcourir chaque page du PDF
        for page in pdf.pages:
            # Extraire le texte de la page
            text += page.extract_text()

    # Créer un nouveau document DOCX
    doc = Document()
    # Ajouter le texte extrait au document DOCX
    doc.add_paragraph(text)

    # Sauvegarder le document DOCX
    doc.save(docx_path)

# Spécifier les chemins d'entrée et de sortie
pdf_file = "CV france IA Parser/page10.pdf"
docx_file = "CV france IA Parser/page10.docx"

# Appeler la fonction de conversion
pdf_to_docx(pdf_file, docx_file)

# %%
import docx2txt
import nltk

# %%
import docx2txt
 
 
def extract_text_from_docx(docx_path):
    txt = docx2txt.process(docx_path)
    if txt:
        return txt.replace('\t', ' ')
    return None
 
 
if __name__ == '__main__':
    print(extract_text_from_docx('CV france IA Parser/page10.docx'))
# Out:
# OUATTARA MOUSSA
# Data Analytics
# Rythme alterné : 3 jours à l'école, 1 semaine et
# demie en entreprise
# COMPETENCES
# Biostatistique/statistiques
# Inserm de PARCC, Hôpital Georges Pompidou
# INFORMATIONS PERSONNELLES
# - Gestion de projet d'étude intitule "Etude
# CADRE/BIOCADRE
# - Je suis disponible immédiatement ; - Data management :
# - Je suis mobile ; - Description des variables qualitatives et quantitatives;
# - J'appartiens à la génération numérique et maitrise - Recherche des données aberrantes et des doublons ;
# les logiciels statistiques, les systèmes d'exploitation - Analyse qualitatives et quantitatives de la base.
# des Routeurs et Serveurs CISCO, les outils et
# Informatique
# technologies des réseaux sociaux, avec des résultats
# prouvés lorsqu'il s'agit de faire l'analyse statistique - Logiciel statistiques :
# et la gestion de base de donnée. - R ; - SAS ; Python ;
# - Word ; - Excel; - PowerPoint et Access;
# - Réseau informatique (Certificat CISCO).
# ...

# %%
import docx2txt
import nltk
 
nltk.download('stopwords')
 
# you may read the database from a csv file or some other database
SKILLS_DB = [
    'machine learning',
    'data science',
    'python',
    'word',
    'marketing',
    'English',
]
 
 
def extract_text_from_docx(docx_path):
    txt = docx2txt.process(docx_path)
    if txt:
        return txt.replace('\t', ' ')
    return None
 
 
def extract_skills(input_text):
    stop_words = set(nltk.corpus.stopwords.words('french'))
    word_tokens = nltk.tokenize.word_tokenize(input_text)
 
    # remove the stop words
    filtered_tokens = [w for w in word_tokens if w not in stop_words]
 
    # remove the punctuation
    filtered_tokens = [w for w in word_tokens if w.isalpha()]
 
    # generate bigrams and trigrams (such as artificial intelligence)
    bigrams_trigrams = list(map(' '.join, nltk.everygrams(filtered_tokens, 2, 3)))
 
    # we create a set to keep the results in.
    found_skills = set()
 
    # we search for each token in our skills database
    for token in filtered_tokens:
        if token.lower() in SKILLS_DB:
            found_skills.add(token)
 
    # we search for each bigram and trigram in our skills database
    for ngram in bigrams_trigrams:
        if ngram.lower() in SKILLS_DB:
            found_skills.add(ngram)
 
    return found_skills
 
 
if __name__ == '__main__':
    text = extract_text_from_docx('CV france IA Parser/page10.docx')
    skills = extract_skills(text)
 
    print(skills)
# Out:
# {'Python', 'Word', 'Marketing'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/choukigueddar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
